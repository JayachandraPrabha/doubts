# %%
import pandas as pd

# %%
dataset=pd.read_csv("PrePlacement.csv")
dataset
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0      1.0  67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1      2.0  79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2      3.0  65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3      4.0  56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4      5.0  85.80  73.60     73.30     96.8  55.50  390000.0      M  Central
# ..     ...    ...    ...       ...      ...    ...       ...    ...      ...
# 210  211.0  80.60  82.00     77.60     91.0  74.49  390000.0      M   Others
# 211  212.0  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  213.0  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  214.0  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  215.0  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
colName=dataset.columns
colName
# Out:
# Index(['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary',
#        'gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex',
#        'specialisation', 'status'],
#       dtype='object')

# %%
dataset['gender'].dtype
# Out:
# dtype('O')

# %%
qual=[]
quan=[]
for colName in dataset[colName]:
    if(dataset[colName].dtype=='O'):
        qual.append(colName)
    else:
        quan.append(colName)

# %%
qual
# Out:
# ['gender',
#  'ssc_b',
#  'hsc_b',
#  'hsc_s',
#  'degree_t',
#  'workex',
#  'specialisation',
#  'status']

# %%
quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset[quan].cov()
# Out:
#                   sl_no          ssc_p          hsc_p       degree_p  \
# sl_no       3870.000000     -52.641355     -59.598879     -41.465047
# ssc_p        -52.641355     117.228377      58.853253      42.702550
# hsc_p        -59.598879      58.853253     112.063731      33.684453
# degree_p     -41.465047      42.702550      33.684453      53.604710
# etest_p       52.556168      37.659225      33.838355      22.078774
# mba_p          8.102336      24.535952      21.517688      17.185200
# salary   -164476.635514  895294.291241  702890.336014  463930.322104
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336 -1.644766e+05
# ssc_p         37.659225      24.535952  8.952943e+05
# hsc_p         33.838355      21.517688  7.028903e+05
# degree_p      22.078774      17.185200  4.639303e+05
# etest_p      176.251018      16.886973  3.479242e+05
# mba_p         16.886973      34.028376  1.067778e+05
# ...

# %%
# Covariance is nothing but the variance between two columns
# Covariance types:Large positive, zero normal, Large negative
# Difference between --> etest_p & mba_p --> 16.886973 (Positive covariance)
# Difference between --> degree_p & etest_p --> 22.078774 (Positive covariance)

# %%
dataset[quan].corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.090500 -0.091039  0.063636  0.022327 -0.019367
# ssc_p    -0.078155  1.000000  0.513478  0.538686  0.261993  0.388478  0.605710
# hsc_p    -0.090500  0.513478  1.000000  0.434606  0.240775  0.348452  0.486374
# degree_p -0.091039  0.538686  0.434606  1.000000  0.227147  0.402376  0.464159
# etest_p   0.063636  0.261993  0.240775  0.227147  1.000000  0.218055  0.191970
# mba_p     0.022327  0.388478  0.348452  0.402376  0.218055  1.000000  0.134084
# salary   -0.019367  0.605710  0.486374  0.464159  0.191970  0.134084  1.000000

# %%
# correlation is the relation between two columns
# Correlation types: 
# Positive (input/independent variable is directly proprtional to output/independent variable)
    #perfect positive (r=1)
    #high degree of positive (r> +high or 0.95)
    #low degree of positive (r<+low or 0.54)
# Negative (input/independent variable is indirectly/inversly proprtional to output/independent variable)
    #perfect Negative (r=1)
    #high degree of Negative (r<-low or -0.54)
    #low degree of Negative (r>-high or -0.94)
# Zero (no pattern or relation ship between input/independent variable & output/independent variable)
# Relation between --> mba_p & salary --> 0.134084% (low Positive correlation, r<0.54)

# %% [markdown]
# # Colinearity & Multi colinarity

# %%
dataset.drop('sl_no',inplace=True,axis=1)

# %%
dataset.columns
# Out:
# Index(['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary', 'gender',
#        'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation',
#        'status'],
#       dtype='object')

# %%
import seaborn as sns

# %%
sns.pairplot(dataset)
# Out:
# C:\Users\jayac\AppData\Local\anaconda3\envs\aiml\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
colName=dataset.columns
quan=[]
qual=[]
for colName in dataset[colName]:
    if(dataset[colName].dtype=='O'):
        qual.append(colName)
    else:
        quan.append(colName)

# %%
quan
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
def cal_vif(X):
    from statsmodels.stats.outliers_influence import variance_inflation_factor
    vif=pd.DataFrame()
    vif['Variables']=X.columns
    vif['VIF']=[variance_inflation_factor(X.values,i) for i in range(X.shape[1])]
    return vif
# Minimal multicolinearity is requried foor a good model
# VIF value is =1, no correlation, VIF<3 to 5 less correlation, VIF>5 more correlated values
# created a function & a table whose columns as variables & VIF, 
# with the help of the varaiance inflation factor, considering the values in the columns of the dataset, we can put VIF values

# %%
# cal_vif(dataset[['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']])
cal_vif(dataset[['etest_p','salary']])
# Out:
#   Variables       VIF
# 0   etest_p  3.069467
# 1    salary  3.069467

# %% [markdown]
# # T-test

# %% [markdown]
# Independent samples --> Unpaired T-Test
#
# Group= Different
#
# Condition= Same
#
# Dependent samples --> Paired T-Test
#
# Group= Same
#
# Condition= Different

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  390000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  390000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.dropna()
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  390000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  390000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
# dataset[dataset['gender']=='M']
dataset[dataset['gender']=='M']['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3           0.0
# 4      390000.0
#          ...
# 209    216000.0
# 210    390000.0
# 211    275000.0
# 212    295000.0
# 214         0.0
# Name: salary, Length: 139, dtype: float64

# %%
# Independent - Unpaired T-Test (Group-same,condition-different)
# Group-Gender(M/F), Condition-Salary

from scipy.stats import ttest_ind
male=dataset[dataset['gender']=='M']['salary']
female=dataset[dataset['gender']=='M']['salary']
ttest_ind(male,female)
# Out:
# TtestResult(statistic=0.0, pvalue=1.0, df=276.0)

# %%
from scipy.stats import ttest_ind
central=dataset[dataset['ssc_b']=='Central']['salary']
others=dataset[dataset['ssc_b']=='Others']['salary']
ttest_ind(central,others)
# Out:
# TtestResult(statistic=-0.8801039252988343, pvalue=0.37979491307053137, df=213.0)

# %%
# dependent - paired t-test (Group==different, Condition=same)
# Group=M, condition=ssc_p,hsc_p

from scipy.stats import ttest_rel
male1=dataset[dataset['gender']=='M']['ssc_p']
male2=dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male1,male2)
# Out:
# TtestResult(statistic=0.6842940392688153, pvalue=0.4949370716000775, df=138)

# %%
from scipy.stats import ttest_rel
com1=dataset[dataset['hsc_s']=='Commerce']['etest_p']
com2=dataset[dataset['hsc_s']=='Commerce']['mba_p']
ttest_rel(com1,com2)
# Out:
# TtestResult(statistic=7.868552092606871, pvalue=2.462926468454984e-12, df=112)

# %% [markdown]
# # Hypothesis testing

# %%
# Hypothesis testing: Null hypothesis:(-), alternate hypothesis:(+)
# if p-value<0.05 --> reject the null hypothesis, accept the alternate hypothesis

# %%
# Statement: SSC_P & HSC_P of male have similarity?
# Null hypothesis: SSC_P & HSC_P of male have no similarity
# Alternate hypothesis: SSC_P & HSC_P of male have similarity

# %%
# dependent--> paired ttest --> group-different, condition-same, n-c
from scipy.stats import ttest_rel
male1=dataset[dataset['gender']=='M']['ssc_p']
male2=dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male1,male2)
# Out:
# TtestResult(statistic=0.6842940392688153, pvalue=0.4949370716000775, df=138)

# %%
# pvalue: 0.49>0.05, condition fails so null hypothesis is rejected & alternate hypothesis is selected
# so, ssc_p & hsc_p of male have similarity

# %% [markdown]
# # ANOVO - Analysis of variance

# %%
import scipy.stats as stats
stats.f_oneway(dataset['ssc_p'],dataset['hsc_p'],dataset['degree_p'])
# Out:
# F_onewayResult(statistic=0.695991304348204, pvalue=0.4989557472581533)

# %%
# dataset.isnull().sum()
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  390000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  390000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
# import pandas as pd
# import numpy as np
# # create dataframe
# # dataframe=dataset
# # Conduct the two-way ANOVA:
# import statsmodels.api as sm
# from statsmodels.formula.api import ols
# model = ols(dataset['mba_p']+dataset['etest_p'],data=dataset).fit()
# result = sm.stats.anova_lm(model, type=2)
# print(result)

# %%
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43       0.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  390000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  390000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22       0.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset.columns
# Out:
# Index(['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary', 'gender',
#        'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation',
#        'status'],
#       dtype='object')

# %%
df=dataset[['mba_p','etest_p','salary']]

# %%
dff=df[:10]
dff
# Out:
#    mba_p  etest_p    salary
# 0  58.80    55.00  270000.0
# 1  66.28    86.50  200000.0
# 2  57.80    75.00  250000.0
# 3  59.43    66.00       0.0
# 4  55.50    96.80  390000.0
# 5  51.58    55.00       0.0
# 6  53.29    74.28       0.0
# 7  62.14    67.00  252000.0
# 8  61.29    91.34  231000.0
# 9  52.21    54.00       0.0

# %%
dff.isnull().sum()
# Out:
# mba_p      0
# etest_p    0
# salary     0
# dtype: int64

# %%
# dff.infer_objects().sum()
# Out:
# mba_p          578.32
# etest_p        720.92
# salary     1593000.00
# dtype: float64

# %%
# 2way anova:
import statsmodels.api as sm
from statsmodels.formula.api import ols

#perform two-way ANOVA
model = ols('salary ~ C(mba_p) + C(etest_p) + C(mba_p):C(etest_p)', data=dff).fit()
# model = ols('height ~ C(water) + C(sun) + C(water):C(sun)', data=df).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
# C:\Users\jayac\AppData\Local\anaconda3\envs\aiml\Lib\site-packages\statsmodels\regression\linear_model.py:1716: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid
# C:\Users\jayac\AppData\Local\anaconda3\envs\aiml\Lib\site-packages\statsmodels\base\model.py:1529: RuntimeWarning: invalid value encountered in multiply
#   cov_p = self.normalized_cov_params * scale
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 8
#       6 model = ols('salary ~ C(mba_p) + C(etest_p) + C(mba_p):C(etest_p)', data=dff).fit()
#       7 # model = ols('height ~ C(water) + C(sun) + C(water):C(sun)', data=dff).fit()
# ----> 8 sm.stats.anova_lm(model, typ=2)
#
# File ~\AppData\Local\anaconda3\envs\aiml\Lib\site-packages\statsmodels\stats\anova.py:349, in anova_lm(*args, **kwargs)
#     347 if len(args) == 1:
# ...
